# %%
pip install pandas

# %%
pip install matplotlib

# %% [markdown]
# CASE: O vendedor de Pirozhki
#
# Vladimir Sidorov desistiu de seu trabalho convencional na KGB e decidiu empreender em 2010 no ramo alimentício. Com suas economias abriu um foodtruck no bairro do Ipiranga – SP especializado na venda de Pirozhki, onde seu grande diferencial era trabalhar com ingredientes importados dando uma qualidade extraordinária ao produto. Após o crescimento das vendas, a modalidade delivery foi implementada para auxiliar a empresa. Vladimir era extremamente popular no bairro, todos o conheciam, mas em 2019 se mudou para um ponto melhor e não tivemos mais notícia. Os últimos dados compartilhados das vendas de Vlad foram disponibilizados antes de sua partida.

# %%
import pandas as pd

vendas = {
    'ANO': [2010,2011,2012,2014,2017,2018,2019],
    'VENDAS': [723,	814,	905, 1087, 1360,	1451, 1542]
}
tabela = pd.DataFrame(vendas)
print(tabela)
# Out:
#     ANO  VENDAS
# 0  2010     723
# 1  2011     814
# 2  2012     905
# 3  2014    1087
# 4  2017    1360
# 5  2018    1451
# 6  2019    1542

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.set_xlim(0, 9)
ax.set_ylim(0, 1700)

pontos = [(0, 723), (1, 814), (2, 905), (4, 1087), (7, 1360), (8, 1451), (9, 1542)]
cores = ['black', 'black', 'black', 'black', 'black', 'black', 'black']
rotulos = [723,	814,	905, 1087, 1360,	1451, 1542]

for ponto, cor, rotulo in zip(pontos, cores, rotulos):
    ax.plot(ponto[0], ponto[1], marker='o', markersize=4, color=cor)
    ax.text(ponto[0] + 0.2, ponto[1] + 0.5, rotulo, fontsize=10)

ax.plot([0,9], [723, 1542], color='black', linewidth=1)

ax.set_xlabel('Anos')
ax.set_ylabel('Vendas')

plt.grid(True)
plt.show()

# %% [markdown]
# 1.	Qual coeficiente angular?
# 2.	Desenvolva um código em python que calcule estatisticamente as vendas em qualquer ano desejado

# %%
#1.
#A reta passa por (0,723) e por (1,814), portanto:
ca = (814-723)/(1-0)
print("O coeficiente angular é:",ca)
# Out:
# O coeficiente angular é: 91.0

# %%
#2.
#Interceptação em y = 723
int_y = 723
x = 10
eq = 91*x+int_y
print("Vendas em 2020:",eq)
# Out:
# Vendas em 2020: 1633

# %%
#Gráfico incluindo vendas em 2020

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.set_xlim(0, 10)
ax.set_ylim(0, 1700)

ax.plot([0,10], [723, 1633], color='black', linewidth=1)

pontos = [(0, 723), (1, 814), (2, 905), (4, 1087), (7, 1360), (8, 1451), (9, 1542), (10,1633)]
cores = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black']
rotulos = [723,	814,	905, 1087, 1360,	1451, 1542, 1633]

for ponto, cor, rotulo in zip(pontos, cores, rotulos):
    ax.plot(ponto[0], ponto[1], marker='o', markersize=4, color=cor)
    ax.text(ponto[0] + 0.2, ponto[1] + 0.5, rotulo, fontsize=10)

# Adicionar rótulos aos eixos
ax.set_xlabel('Anos')
ax.set_ylabel('Vendas')

plt.grid(True)
plt.show()

# %% [markdown]
# 3.	Considerando sua opinião, qual o total de venda em 2021?
# 4.	Considerando sua opinião, qual o total de venda em 2023?

# %%
#Vendas em 2021 e 2023

x = 11
eq = 91*x+723
print("Vendas em 2021:",eq)

x = 13
eq = 91*x+723
print("Vendas em 2023:",eq)
# Out:
# Vendas em 2021: 1724
# Vendas em 2023: 1906

# %%
#Gráfico incluindo vendas em 2021 e 2023

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.set_xlim(0, 13)
ax.set_ylim(0, 2000)

ax.plot([0,13], [723, 1906], color='black', linewidth=1)

pontos = [(0, 723), (1, 814), (2, 905), (4, 1087), (7, 1360), (8, 1451), (9, 1542), (10,1633), (11,1724), (13,1906)]
cores = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black']
rotulos = [723,	814,	905, 1087, 1360,	1451, 1542, 1633, 1724, 1906]

for ponto, cor, rotulo in zip(pontos, cores, rotulos):
    ax.plot(ponto[0], ponto[1], marker='o', markersize=4, color=cor)
    ax.text(ponto[0] + 0.2, ponto[1] + 0.5, rotulo, fontsize=10)

# Adicionar rótulos aos eixos
ax.set_xlabel('Anos')
ax.set_ylabel('Vendas')

plt.grid(True)
plt.show()
